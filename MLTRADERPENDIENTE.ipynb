# %%
from lumibot.brokers import Alpaca
from lumibot.backtesting import YahooDataBacktesting
from lumibot.strategies.strategy import Strategy
from lumibot.traders import Trader
from datetime import datetime
from alpaca_trade_api import REST
from datetime import timedelta
from finbert_utils import estimate_sentiment

API_KEY = "YOUR API KEY"
API_SECRET = "YOUR API SECRET"
BASE_URL = "THE URL OF ALPACA"

ALPACA_CREDS = {
    "API_KEY":API_KEY,
    "API_SECRET": API_SECRET,
    "PAPER": True
}


class SRCTRADINGTROLL(Strategy):
    def initialize(self, symbol:str="SPY", cash_at_risk:float=.5):
        self.symbol = symbol
        self.sleeptime = "24H"
        self.last_trade = None
        self.cash_at_risk = cash_at_risk
        self.api = REST(base_url=BASE_URL, key_id=API_KEY, secret_key=API_SECRET)

    def position_sizing(self):
        cash = self.get_cash()
        last_price = self.get_last_price(self.symbol)
        quantity = round(cash * self.cash_at_risk / last_price,0)
        return cash, last_price, quantity

    def get_dates(self):
        today = self.get_datetime()
        three_days_prior = today - timedelta(days=3)
        return today.strftime('%Y-%m-%d'), three_days_prior.strftime('%Y-%m-%d')

    def get_sentiment(self):
        today, three_days_prior = self.get_dates()
        news = self.api.get_news(symbol=self.symbol,
                                 start=three_days_prior,
                                 end=today)
        news = [ev.__dict__["_raw"]["headline"] for ev in news]
        probability, sentiment = estimate_sentiment(news)
        return probability, sentiment

    def on_trading_iteration(self):
        cash, last_price, quantity = self.position_sizing()
        probability, sentiment = self.get_sentiment()

        if cash > last_price:
            if sentiment == "positive" and probability > .999:
                if self.last_trade == "sell":
                    self.sell_all()
                order = self.create_order(
                    self.symbol,
                    quantity,
                    "buy",
                    type="bracket",
                    take_profit_price=last_price*1.20,
                    stop_loss_price=last_price*.95
                )
                self.submit_order(order)
                self.last_trade = "buy"
            elif sentiment == "negative" and probability > .999:
                if self.last_trade == "buy":
                    self.sell_all()
                order = self.create_order(
                    self.symbol,
                    quantity,
                    "sell",
                    type="bracket",
                    take_profit_price=last_price*.8,
                    stop_loss_price=last_price*1.05
                )
                self.submit_order(order)
                self.last_trade = "sell"

start_date = datetime(2023,12,31)
end_date = datetime(2025,8,7)
broker = Alpaca(ALPACA_CREDS)
strategy = SRCTRADINGTROLL(name='src_trading_troll', broker=broker,
                         parameters={"symbol":"SPY",
                                     "cash_at_risk":.5})
strategy.backtest(
    YahooDataBacktesting,
    start_date,
    end_date,
    parameters={"symbol":"SPY", "cash_at_risk":.5}
)
# trader = Trader()
# trader.add_strategy(strategy)
# trader.run_all()
# Out:
# 2025-08-30 11:39:56,970 | ERROR | _strategy.py:update_broker_balances:641 | [src_trading_troll] Error getting broker balances: {"message": "forbidden."}
# error during websocket communication: failed to authenticate
# Traceback (most recent call last):
#   File "C:\Users\josep\anaconda3\Lib\site-packages\alpaca\trading\stream.py", line 171, in _run_forever
#     await self._start_ws()
#   File "C:\Users\josep\anaconda3\Lib\site-packages\alpaca\trading\stream.py", line 132, in _start_ws
#     await self._auth()
#   File "C:\Users\josep\anaconda3\Lib\site-packages\alpaca\trading\stream.py", line 79, in _auth
#     raise ValueError("failed to authenticate")
# ValueError: failed to authenticate
# C:\Users\josep\anaconda3\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# C:\Users\josep\anaconda3\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# C:\Users\josep\anaconda3\Lib\ast.py:587: DeprecationWarning:
#
# Attribute s is deprecated and will be removed in Python 3.14; use value instead
#
# C:\Users\josep\anaconda3\Lib\site-packages\executing\executing.py:713: DeprecationWarning:
#
# ast.Str is deprecated and will be removed in Python 3.14; use ast.Constant instead
#
# C:\Users\josep\anaconda3\Lib\ast.py:587: DeprecationWarning:
#
# Attribute s is deprecated and will be removed in Python 3.14; use value instead
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\alpaca\common\rest.py:198, in RESTClient._one_request(self, method, url, opts, retry)
#     197 try:
# --> 198     response.raise_for_status()
#     199 except HTTPError as http_error:
#     200     # retry if we hit Rate Limit
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://paper-api.alpaca.markets/v2/positions
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[2], line 84
#      82 end_date = datetime(2025,8,7)
#      83 broker = Alpaca(ALPACA_CREDS)
# ---> 84 strategy = SRCTRADINGTROLL(name='src_trading_troll', broker=broker,
#      85                          parameters={"symbol":"SPY",
#      86                                      "cash_at_risk":.5})
#      87 strategy.backtest(
#      88     YahooDataBacktesting,
#      89     start_date,
#      90     end_date,
#      91     parameters={"symbol":"SPY", "cash_at_risk":.5}
#      92 )
#
# File ~\anaconda3\Lib\site-packages\lumibot\strategies\_strategy.py:425, in _Strategy.__init__(self, broker, data_source, minutes_before_closing, minutes_before_opening, minutes_after_closing, sleeptime, stats_file, risk_free_rate, benchmark_asset, analyze_backtest, backtesting_start, backtesting_end, quote_asset, starting_positions, filled_order_callback, name, budget, parameters, buy_trading_fees, sell_trading_fees, force_start_immediately, discord_webhook_url, account_history_db_connection_str, db_connection_str, strategy_id, discord_account_summary_footer, should_backup_variables_to_database, should_send_summary_to_discord, save_logfile, lumiwealth_api_key, include_cash_positions, **kwargs)
#     422     self.update_broker_balances()
#     424     # Set initial positions if live trading.
# --> 425     self.broker._set_initial_positions(self)
#     426 else:
#     427     # If budget is not provided to run_backtest, default it
#     428     effective_budget = budget
#
# File ~\anaconda3\Lib\site-packages\lumibot\brokers\broker.py:794, in Broker._set_initial_positions(self, strategy)
#     792 def _set_initial_positions(self, strategy):
#     793     """Set initial positions"""
# --> 794     positions = self._pull_positions(strategy)
#     795     for pos in positions:
#     796         if pos.quantity != 0.0:
#
# File ~\anaconda3\Lib\site-packages\lumibot\brokers\alpaca.py:429, in Alpaca._pull_positions(self, strategy)
#     426 def _pull_positions(self, strategy):
#     427     """Get the account positions. return a list of
#     428     position objects"""
# --> 429     response = self._pull_broker_positions(strategy)
#     430     # Handle case where strategy might be None
#     431     strategy_name = strategy.name if strategy and hasattr(strategy, 'name') else "default"
#
# File ~\anaconda3\Lib\site-packages\lumibot\brokers\alpaca.py:414, in Alpaca._pull_broker_positions(self, strategy)
#     412 def _pull_broker_positions(self, strategy=None):
#     413     """Get the broker representation of all positions"""
# --> 414     response = self.api.get_all_positions()
#     415     return response
#
# File ~\anaconda3\Lib\site-packages\alpaca\trading\client.py:244, in TradingClient.get_all_positions(self)
#     235 def get_all_positions(
#     236     self,
#     237 ) -> Union[List[Position], RawData]:
#     238     """
#     239     Gets all the current open positions.
#     240
#     241     Returns:
#     242         List[Position]: List of open positions.
#     243     """
# --> 244     response = self.get("/positions")
#     246     if self._use_raw_data:
#     247         return response
#
# File ~\anaconda3\Lib\site-packages\alpaca\common\rest.py:225, in RESTClient.get(self, path, data, **kwargs)
#     212 def get(
#     213     self, path: str, data: Optional[Union[dict, str]] = None, **kwargs
#     214 ) -> HTTPResult:
#     215     """Performs a single GET request
#     216
#     217     Args:
#    (...)
#     223         dict: The response
#     224     """
# --> 225     return self._request("GET", path, data, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\alpaca\common\rest.py:131, in RESTClient._request(self, method, path, data, base_url, api_version)
#     129 while retry >= 0:
#     130     try:
# --> 131         return self._one_request(method, url, opts, retry)
#     132     except RetryException:
#     133         time.sleep(self._retry_wait)
#
# File ~\anaconda3\Lib\site-packages\alpaca\common\rest.py:207, in RESTClient._one_request(self, method, url, opts, retry)
#     204     # raise API error for all other errors
#     205     error = response.text
# --> 207     raise APIError(error, http_error)
#     209 if response.text != "":
#     210     return response.json()
#
# APIError: {"message": "forbidden."}
